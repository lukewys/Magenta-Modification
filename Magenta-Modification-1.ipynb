# %% [markdown]
# # Magenta魔改记-1：MIDI文件读取
#
# Magenta支持MIDI（.mid/.midi）文件与MusicXML（.xml/.mxl）、ABC数据（http://abcnotation.com，没有测试过）文件做训练数据。
# 通常，制作数据集的步骤是，先将原始文件转化成单个tfrecord文件保存，再根据每个不同的模型进行不同的数据清洗与处理。
#
# 那么这篇文章先着重分析第一步，将MIDI/MusicXML文件直接转换成tfrecord：
# 对应github中的提示：
# https://github.com/tensorflow/magenta/tree/master/magenta/scripts#building-your-dataset
#
# 上述链接中的命令行如下：
#
# ```
# INPUT_DIRECTORY=<folder containing MIDI and/or MusicXML files. can have child folders.>
#
# # TFRecord file that will contain NoteSequence protocol buffers.
# SEQUENCES_TFRECORD=/tmp/notesequences.tfrecord
#
# convert_dir_to_note_sequences \
#   --input_dir=$INPUT_DIRECTORY \
#   --output_file=$SEQUENCES_TFRECORD \
#   --recursive
# ```
#
# 这一步的bazel命令行如下（摘自源代码注释）：
#
# ```
# Example usage:
#   $ bazel build magenta/scripts:convert_dir_to_note_sequences
#
#   $ ./bazel-bin/magenta/scripts/convert_dir_to_note_sequences \
#     --input_dir=/path/to/input/dir \
#     --output_file=/path/to/tfrecord/file \
#     --num_threads=4 \
# --log=INFO
# ```
#
# 可以看到，两个命令行的参数内容都不同，可见Magenta项目组对于文档或API的介绍并没有进行认真的维护。
#
# ## 魔改-1.0：
#
#
# 那么下面介绍如何修改这一步预处理的参数。
#
# 这一步运行的文件位置如下：
# https://github.com/tensorflow/magenta/blob/master/magenta/scripts/convert_dir_to_note_sequences.py
#
#
#
# 打开源代码我们可以看到，程序一开始就定义了一系列tf.flag：
#
# ```
# FLAGS = tf.app.flags.FLAGS
#
# tf.app.flags.DEFINE_string('input_dir', None,
#                            'Directory containing files to convert.')
# #输入路径
# tf.app.flags.DEFINE_string('output_file', None,
#                            'Path to output TFRecord file. Will be overwritten '
#                            'if it already exists.')
# #输出路径
# tf.app.flags.DEFINE_bool('recursive', False,
#                          'Whether or not to recurse into subdirectories.')
# #是否递归查找子路径的文件
# tf.app.flags.DEFINE_integer('num_threads', 1,
#                             'Number of worker threads to run in parallel.')
# #线程数量。如果数据文件很多且CPU性能足够的话，建议设置一个相对大的值
# tf.app.flags.DEFINE_string('log', 'INFO',
#                            'The threshold for what messages will be logged '
#                            'DEBUG, INFO, WARN, ERROR, or FATAL.')
# #显示消息的类型
# ```
#
# 这是Tensorflow中用于从命令行传递参数的变量，基于argparse实现。如果在运行时不输入参数，则会按程序中默认填写的参数运行。
# 因此可以看到，这一个程序共有5个参数，而上面两种命令行方法都没有写出所有的变量，但上述两种方法都能运行，因为没有默认值的变量只有输入路径和输出路径两个。
# 通过
# ```
# python convert_dir_to_note_sequences.py.py –h
# ```
#
# 可以显示注释信息和参数及其详情。
# 因此，我们在自定义参数时，既可以在命令行运行时输入：
# ```
# python convert_dir_to_note_sequences.py --input_dir=E:\Magenta\Dataset\raw\bach --output_file=E:\Magenta\Dataset\pre\bach.tfrecord --recursive=True --num_threads=4
# ```
# 同样，我们也可以把前面这几行当做超参数变量声明，直接在程序里改（第二个参数），然后运行。

# %% [markdown]
# ## 魔改-2.0
#
# ###### Magenta version:0.3.6
#
# 接下来介绍这一步的详细原理以及文件储存的数据类型。
#
# 源代码地址：
# https://github.com/tensorflow/magenta/blob/master/magenta/scripts/convert_dir_to_note_sequences.py
#
# 在本程序中，大致的运行步骤为：
# 1. 先检测输入路径（以及子路径）中所有符合要求的文件，生成文件路径列表。
# 2. 再根据列表多线程的处理数据。
# 3. 最后再存成.tfrecord文件。
#
# 第一步对应queue_conversions(root_dir, sub_dir, pool, recursive=False)函数，在此不多展开。
#
# 第二步对应convert_midi(root_dir, sub_dir, full_file_path)、
# convert_musicxml(root_dir, sub_dir, full_file_path)两个函数。顾名思义就是针对midi和xml文件的处理函数（一开始说的ABC数据处理函数未知）。它们的参数以及返回值可以在函数注释中找到详细的介绍。简单来说就是输入文件路径、文件所在文件夹路径、上一级路径，输出NoteSequence proto，一个在Magenta项目中用来表示音符序列的数据类型。
#
# 第三步则对应convert_directory(root_dir, output_file, num_threads,recursive=False)，是总的函数。

# %% [markdown]
# 首先我们可以把这个文件导入：

# %%
import tensorflow as tf
import magenta as mgt
import magenta.scripts.convert_dir_to_note_sequences as cvrt

# %% [markdown]
# 导入之后我们也可以用查看子类的方式查看它的FLAGS参数：

# %%
print(cvrt.FLAGS)
# Out:
# magenta.scripts.convert_dir_to_note_sequences:
#   --input_dir: Directory containing files to convert.
#   --log: The threshold for what messages will be logged DEBUG, INFO, WARN,
#     ERROR, or FATAL.
#     (default: 'INFO')
#   --num_threads: Number of worker threads to run in parallel.
#     (default: '1')
#     (an integer)
#   --output_file: Path to output TFRecord file. Will be overwritten if it already
#     exists.
#   --[no]recursive: Whether or not to recurse into subdirectories.
#     (default: 'false')
#
# absl.flags:
#   --flagfile: Insert flag definitions from the given file into the command line.
#     (default: '')
#   --undefok: comma-separated list of flag names that it is okay to specify on
#     the command line even if the program does not define a flag with that name.
#     IMPORTANT: flags in this list that have arguments MUST use the --flag=value
#     format.
#     (default: '')

# %%
#加这行是因为jupyter notebook对tf.app.flags.FLAGS有bug
#见https://github.com/tensorflow/tensorflow/issues/17702
tf.app.flags.DEFINE_string('f', '', 'kernel')

# %% [markdown]
# 因此我们也可以用修改FLAGS子类参数的方法运行本程序：
#
# 我这里以及下面的代码中都采用了绝对路径，所以在自己运行时请修改路径。文件会附在github中。

# %%
cvrt.FLAGS.input_dir=r'E:\Magenta\Dataset\xml_raw'
cvrt.FLAGS.output_file=r'E:\Magenta\Dataset\pre\bach.tfrecord'
cvrt.FLAGS.num_threads=4
cvrt.FLAGS.recursive=True
cvrt.FLAGS.log='INFO'

# %%
tf.app.run(cvrt.main)
# Out:
# INFO:tensorflow:Converting files in 'E:\Magenta\Dataset\xml_raw\'.
# INFO:tensorflow:0 files converted.
# INFO:tensorflow:Converted MusicXML file E:\Magenta\Dataset\xml_raw\bwv1.6.mxl.
# INFO:tensorflow:Converted MusicXML file E:\Magenta\Dataset\xml_raw\bwv2.6.mxl.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# 如上所说，这个文件包含convert_midi(root_dir, sub_dir, full_file_path)、convert_musicxml(root_dir, sub_dir, full_file_path)两个函数。
#
# 下面我们分别来运行一下转换函数并看一下它们返回的结果。

# %%
full_file_path_xml=r'E:\Magenta\Dataset\xml_raw\bwv1.6.mxl'
root_dir_xml=r'E:\Magenta\Dataset\xml_raw'
sub_dir_xml=r'E:\Magenta\Dataset\xml_raw'
sequence_xml=cvrt.convert_musicxml(root_dir_xml, sub_dir_xml, full_file_path_xml)
# Out:
# INFO:tensorflow:Converted MusicXML file E:\Magenta\Dataset\xml_raw\bwv1.6.mxl.

# %% [markdown]
# 我们可以看到sequence_xml是一个基于Google protobuf的数据类型。

# %%
print(type(sequence_xml))
# Out:
# <class 'magenta.protobuf.music_pb2.NoteSequence'>

# %%
print(sequence_xml)
# Out:
# id: "/id/musicxml/xml_raw/efab6353dd5ebf096204bc6316d1d2f003b156c7"
# filename: "E:\\Magenta\\Dataset\\xml_raw\\bwv1.6.mxl"
# collection_name: "xml_raw"
# ticks_per_quarter: 220
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# time_signatures {
#   time: 38.5
#   numerator: 3
#   denominator: 4
# }
# time_signatures {
#   numerator: 1
#   denominator: 4
# }
# time_signatures {
#   time: 0.5
#   numerator: 4
#   denominator: 4
# }
# key_signatures {
#   key: F
# }
# tempos {
#   qpm: 120.0
# }
# notes {
#   pitch: 65
#   velocity: 64
#   end_time: 0.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 0.5
#   end_time: 0.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 0.75
#   end_time: 1.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 1.25
#   end_time: 1.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 1.5
#   end_time: 1.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 1.75
#   end_time: 2.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 2.0
#   end_time: 2.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 2.25
#   end_time: 2.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 2.5
#   end_time: 2.625
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 2.625
#   end_time: 2.75
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 2.75
#   end_time: 2.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 2.875
#   end_time: 3.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 3.0
#   end_time: 3.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 3.25
#   end_time: 3.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 3.5
#   end_time: 4.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 4.0
#   end_time: 4.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 4.5
#   end_time: 4.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 4.75
#   end_time: 4.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 4.875
#   end_time: 5.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 5.0
#   end_time: 5.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 5.25
#   end_time: 5.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 5.375
#   end_time: 5.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 5.5
#   end_time: 5.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 5.75
#   end_time: 6.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 6.0
#   end_time: 6.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 6.25
#   end_time: 6.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 6.5
#   end_time: 6.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 71
#   velocity: 64
#   start_time: 6.75
#   end_time: 6.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 6.875
#   end_time: 7.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 71
#   velocity: 64
#   start_time: 7.0
#   end_time: 7.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 7.5
#   end_time: 8.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 8.0
#   end_time: 8.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 8.5
#   end_time: 8.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 8.75
#   end_time: 9.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 9.0
#   end_time: 9.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 9.25
#   end_time: 9.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 9.5
#   end_time: 9.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 9.75
#   end_time: 10.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 10.0
#   end_time: 10.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 10.25
#   end_time: 10.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 10.5
#   end_time: 10.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 10.75
#   end_time: 10.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 10.875
#   end_time: 11.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 11.0
#   end_time: 11.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 11.25
#   end_time: 11.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 11.375
#   end_time: 11.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 11.5
#   end_time: 12.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 12.0
#   end_time: 12.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 12.5
#   end_time: 12.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 12.75
#   end_time: 13.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 13.0
#   end_time: 13.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 13.25
#   end_time: 13.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 13.5
#   end_time: 13.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 13.75
#   end_time: 14.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 14.0
#   end_time: 14.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 14.25
#   end_time: 14.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 14.5
#   end_time: 14.625
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 14.625
#   end_time: 14.75
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 14.75
#   end_time: 14.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 14.875
#   end_time: 15.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 15.0
#   end_time: 15.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 15.25
#   end_time: 15.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 15.5
#   end_time: 16.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 16.0
#   end_time: 16.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 16.5
#   end_time: 16.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 16.75
#   end_time: 16.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 16.875
#   end_time: 17.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 17.0
#   end_time: 17.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 17.25
#   end_time: 17.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 17.375
#   end_time: 17.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 17.5
#   end_time: 17.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 17.75
#   end_time: 18.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 18.0
#   end_time: 18.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 18.25
#   end_time: 18.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 18.5
#   end_time: 18.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 71
#   velocity: 64
#   start_time: 18.75
#   end_time: 18.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 18.875
#   end_time: 19.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 71
#   velocity: 64
#   start_time: 19.0
#   end_time: 19.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 19.5
#   end_time: 20.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 20.0
#   end_time: 20.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 20.5
#   end_time: 20.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 20.75
#   end_time: 21.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 21.0
#   end_time: 21.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 21.25
#   end_time: 21.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 21.5
#   end_time: 21.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 21.75
#   end_time: 22.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 22.0
#   end_time: 22.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 22.25
#   end_time: 22.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 22.5
#   end_time: 22.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 22.75
#   end_time: 22.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 22.875
#   end_time: 23.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 23.0
#   end_time: 23.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 23.25
#   end_time: 23.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 23.375
#   end_time: 23.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 23.5
#   end_time: 24.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 24.5
#   end_time: 24.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 24.75
#   end_time: 24.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 24.875
#   end_time: 25.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 25.0
#   end_time: 25.125
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 25.125
#   end_time: 25.25
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 25.25
#   end_time: 25.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 25.375
#   end_time: 25.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 25.5
#   end_time: 26.5
#   numerator: 1
#   denominator: 2
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 26.5
#   end_time: 26.625
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 26.625
#   end_time: 26.75
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 26.75
#   end_time: 26.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 26.875
#   end_time: 27.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 27.0
#   end_time: 27.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 27.5
#   end_time: 28.5
#   numerator: 1
#   denominator: 2
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 28.5
#   end_time: 28.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 28.75
#   end_time: 29.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 29.0
#   end_time: 29.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 29.25
#   end_time: 29.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 29.5
#   end_time: 29.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 29.75
#   end_time: 29.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 29.875
#   end_time: 30.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 30.0
#   end_time: 30.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 30.25
#   end_time: 30.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 30.375
#   end_time: 30.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 30.5
#   end_time: 30.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 30.75
#   end_time: 31.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 31.0
#   end_time: 31.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 31.25
#   end_time: 31.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 31.5
#   end_time: 32.25
#   numerator: 3
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 32.25
#   end_time: 32.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 32.5
#   end_time: 32.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 32.75
#   end_time: 32.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 32.875
#   end_time: 33.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 33.0
#   end_time: 33.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 33.5
#   end_time: 33.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 33.75
#   end_time: 34.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 34.0
#   end_time: 34.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 34.25
#   end_time: 34.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 34.375
#   end_time: 34.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 34.5
#   end_time: 35.5
#   numerator: 1
#   denominator: 2
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 35.5
#   end_time: 35.625
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 35.625
#   end_time: 35.75
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 35.75
#   end_time: 35.875
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 35.875
#   end_time: 36.0
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 36.0
#   end_time: 36.5
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 36.5
#   end_time: 36.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 36.75
#   end_time: 37.25
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 37.25
#   end_time: 37.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 37.5
#   end_time: 37.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 37.75
#   end_time: 38.25
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 38.25
#   end_time: 38.5
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 38.5
#   end_time: 38.75
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 38.75
#   end_time: 39.0
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 39.0
#   end_time: 39.25
#   numerator: 1
#   denominator: 8
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 39.25
#   end_time: 39.375
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 39.375
#   end_time: 39.5
#   numerator: 1
#   denominator: 16
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 39.5
#   end_time: 40.0
#   numerator: 1
#   denominator: 4
#   instrument: 7
#   program: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   end_time: 0.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 0.5
#   end_time: 1.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 1.5
#   end_time: 2.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 2.0
#   end_time: 2.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 2.5
#   end_time: 3.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 3.0
#   end_time: 3.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 3.5
#   end_time: 4.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 4.0
#   end_time: 4.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 4.5
#   end_time: 5.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 76
#   velocity: 64
#   start_time: 5.0
#   end_time: 5.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 77
#   velocity: 64
#   start_time: 5.5
#   end_time: 6.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 76
#   velocity: 64
#   start_time: 6.0
#   end_time: 6.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 6.5
#   end_time: 7.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 7.0
#   end_time: 7.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 7.5
#   end_time: 8.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 8.0
#   end_time: 8.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 8.5
#   end_time: 9.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 9.0
#   end_time: 9.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 9.5
#   end_time: 10.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 10.0
#   end_time: 10.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 10.5
#   end_time: 11.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 11.5
#   end_time: 12.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 12.0
#   end_time: 12.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 12.5
#   end_time: 13.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 13.0
#   end_time: 13.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 13.5
#   end_time: 14.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 14.0
#   end_time: 14.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 14.5
#   end_time: 15.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 15.0
#   end_time: 15.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 15.5
#   end_time: 16.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 16.0
#   end_time: 16.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 16.5
#   end_time: 17.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 76
#   velocity: 64
#   start_time: 17.0
#   end_time: 17.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 77
#   velocity: 64
#   start_time: 17.5
#   end_time: 18.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 76
#   velocity: 64
#   start_time: 18.0
#   end_time: 18.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 18.5
#   end_time: 19.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 19.0
#   end_time: 19.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 19.5
#   end_time: 20.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 20.0
#   end_time: 20.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 20.5
#   end_time: 21.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 21.0
#   end_time: 21.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 21.5
#   end_time: 22.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 22.0
#   end_time: 22.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 22.5
#   end_time: 23.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 23.5
#   end_time: 24.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 24.5
#   end_time: 25.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 25.5
#   end_time: 26.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 26.5
#   end_time: 27.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 27.5
#   end_time: 28.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 28.5
#   end_time: 29.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 29.0
#   end_time: 29.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 29.5
#   end_time: 30.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 30.0
#   end_time: 30.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 30.5
#   end_time: 31.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 31.0
#   end_time: 31.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 31.5
#   end_time: 32.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 32.0
#   end_time: 32.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 32.5
#   end_time: 33.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 33.0
#   end_time: 33.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 33.5
#   end_time: 34.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 34.5
#   end_time: 35.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 77
#   velocity: 64
#   start_time: 35.5
#   end_time: 36.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 76
#   velocity: 64
#   start_time: 36.0
#   end_time: 36.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 36.5
#   end_time: 37.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 37.0
#   end_time: 37.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 37.5
#   end_time: 38.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 38.0
#   end_time: 38.5
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 38.5
#   end_time: 39.5
#   numerator: 1
#   denominator: 2
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 39.5
#   end_time: 40.0
#   numerator: 1
#   denominator: 4
#   instrument: 1
#   program: 1
#   part: 1
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   end_time: 0.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 0.5
#   end_time: 1.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 1.5
#   end_time: 2.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 2.0
#   end_time: 2.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 2.5
#   end_time: 3.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 3.0
#   end_time: 3.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 3.5
#   end_time: 4.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 4.0
#   end_time: 4.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 4.5
#   end_time: 5.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 5.0
#   end_time: 5.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 5.5
#   end_time: 5.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 5.75
#   end_time: 6.0
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 6.0
#   end_time: 6.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 6.25
#   end_time: 6.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 6.5
#   end_time: 7.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 7.0
#   end_time: 7.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 7.5
#   end_time: 8.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 8.0
#   end_time: 8.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 8.5
#   end_time: 9.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 9.0
#   end_time: 9.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 9.5
#   end_time: 9.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 9.75
#   end_time: 10.0
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 10.0
#   end_time: 10.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 10.25
#   end_time: 10.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 10.5
#   end_time: 11.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 11.0
#   end_time: 11.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 11.5
#   end_time: 12.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 12.0
#   end_time: 12.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 12.5
#   end_time: 13.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 13.0
#   end_time: 13.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 13.5
#   end_time: 14.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 14.0
#   end_time: 14.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 14.5
#   end_time: 15.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 15.0
#   end_time: 15.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 15.5
#   end_time: 16.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 16.0
#   end_time: 16.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 16.5
#   end_time: 17.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 70
#   velocity: 64
#   start_time: 17.0
#   end_time: 17.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 17.5
#   end_time: 17.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 74
#   velocity: 64
#   start_time: 17.75
#   end_time: 18.0
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 72
#   velocity: 64
#   start_time: 18.0
#   end_time: 18.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 18.25
#   end_time: 18.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 18.5
#   end_time: 19.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 19.0
#   end_time: 19.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 19.5
#   end_time: 20.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 20.0
#   end_time: 20.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 20.5
#   end_time: 21.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 21.0
#   end_time: 21.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 21.5
#   end_time: 21.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 21.75
#   end_time: 22.0
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 22.0
#   end_time: 22.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 22.25
#   end_time: 22.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 22.5
#   end_time: 23.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 23.0
#   end_time: 23.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 23.5
#   end_time: 24.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 24.5
#   end_time: 25.5
#   numerator: 1
#   denominator: 2
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 25.5
#   end_time: 26.5
#   numerator: 1
#   denominator: 2
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 26.5
#   end_time: 26.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 26.75
#   end_time: 26.875
#   numerator: 1
#   denominator: 16
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 26.875
#   end_time: 27.0
#   numerator: 1
#   denominator: 16
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 27.0
#   end_time: 27.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 27.5
#   end_time: 28.5
#   numerator: 1
#   denominator: 2
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 28.5
#   end_time: 29.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 29.0
#   end_time: 29.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 29.5
#   end_time: 30.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 30.0
#   end_time: 30.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 30.5
#   end_time: 31.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 31.0
#   end_time: 31.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 31.5
#   end_time: 32.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 32.0
#   end_time: 32.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 32.5
#   end_time: 33.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 33.0
#   end_time: 33.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 33.25
#   end_time: 33.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 33.5
#   end_time: 34.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 34.0
#   end_time: 34.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 34.5
#   end_time: 35.5
#   numerator: 1
#   denominator: 2
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 35.5
#   end_time: 36.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 69
#   velocity: 64
#   start_time: 36.0
#   end_time: 36.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 67
#   velocity: 64
#   start_time: 36.25
#   end_time: 36.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 36.5
#   end_time: 37.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 37.0
#   end_time: 37.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 37.5
#   end_time: 37.75
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 37.75
#   end_time: 38.0
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 38.0
#   end_time: 38.25
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 38.25
#   end_time: 38.5
#   numerator: 1
#   denominator: 8
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 65
#   velocity: 64
#   start_time: 38.5
#   end_time: 39.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 64
#   velocity: 64
#   start_time: 39.0
#   end_time: 39.5
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 39.5
#   end_time: 40.0
#   numerator: 1
#   denominator: 4
#   instrument: 2
#   program: 1
#   part: 2
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   end_time: 0.5
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 0.5
#   end_time: 1.0
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.5
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 1.5
#   end_time: 2.0
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
# ...
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 58
#   velocity: 64
#   start_time: 37.5
#   end_time: 38.0
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 38.0
#   end_time: 38.25
#   numerator: 1
#   denominator: 8
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 38.25
#   end_time: 38.5
#   numerator: 1
#   denominator: 8
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 38.5
#   end_time: 39.0
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 39.0
#   end_time: 39.125
#   numerator: 1
#   denominator: 16
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 39.125
#   end_time: 39.25
#   numerator: 1
#   denominator: 16
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 39.25
#   end_time: 39.5
#   numerator: 1
#   denominator: 8
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 39.5
#   end_time: 40.0
#   numerator: 1
#   denominator: 4
#   instrument: 3
#   program: 1
#   part: 3
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   end_time: 0.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 0.5
#   end_time: 1.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 1.0
#   end_time: 1.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 1.5
#   end_time: 2.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 45
#   velocity: 64
#   start_time: 2.0
#   end_time: 2.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 46
#   velocity: 64
#   start_time: 2.5
#   end_time: 2.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 2.75
#   end_time: 3.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 3.0
#   end_time: 3.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 3.25
#   end_time: 3.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 3.5
#   end_time: 4.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 4.0
#   end_time: 4.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 58
#   velocity: 64
#   start_time: 4.5
#   end_time: 5.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 5.0
#   end_time: 5.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 5.25
#   end_time: 5.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 5.5
#   end_time: 5.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 59
#   velocity: 64
#   start_time: 5.75
#   end_time: 6.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 6.0
#   end_time: 6.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 6.5
#   end_time: 7.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 7.0
#   end_time: 7.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 7.5
#   end_time: 8.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 8.0
#   end_time: 8.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 46
#   velocity: 64
#   start_time: 8.5
#   end_time: 9.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 9.0
#   end_time: 9.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 9.5
#   end_time: 9.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 9.75
#   end_time: 10.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 10.0
#   end_time: 10.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 10.5
#   end_time: 11.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 41
#   velocity: 64
#   start_time: 11.5
#   end_time: 12.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 12.0
#   end_time: 12.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 12.5
#   end_time: 13.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 13.0
#   end_time: 13.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 13.5
#   end_time: 14.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 45
#   velocity: 64
#   start_time: 14.0
#   end_time: 14.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 46
#   velocity: 64
#   start_time: 14.5
#   end_time: 14.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 14.75
#   end_time: 15.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 15.0
#   end_time: 15.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 15.25
#   end_time: 15.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 15.5
#   end_time: 16.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 16.0
#   end_time: 16.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 58
#   velocity: 64
#   start_time: 16.5
#   end_time: 17.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 17.0
#   end_time: 17.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 17.25
#   end_time: 17.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 17.5
#   end_time: 17.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 59
#   velocity: 64
#   start_time: 17.75
#   end_time: 18.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 18.0
#   end_time: 18.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 18.5
#   end_time: 19.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 19.0
#   end_time: 19.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 19.5
#   end_time: 20.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 20.0
#   end_time: 20.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 46
#   velocity: 64
#   start_time: 20.5
#   end_time: 21.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 21.0
#   end_time: 21.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 21.5
#   end_time: 21.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 21.75
#   end_time: 22.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 22.0
#   end_time: 22.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 22.5
#   end_time: 23.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 41
#   velocity: 64
#   start_time: 23.5
#   end_time: 24.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 24.5
#   end_time: 25.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 25.5
#   end_time: 26.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 26.5
#   end_time: 27.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 27.5
#   end_time: 28.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 28.5
#   end_time: 28.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 28.75
#   end_time: 29.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 29.0
#   end_time: 29.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 29.25
#   end_time: 29.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 29.5
#   end_time: 29.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 29.75
#   end_time: 30.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 52
#   velocity: 64
#   start_time: 30.0
#   end_time: 30.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 30.25
#   end_time: 30.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 30.5
#   end_time: 30.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 30.75
#   end_time: 31.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 31.0
#   end_time: 31.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 31.25
#   end_time: 31.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 31.5
#   end_time: 32.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 58
#   velocity: 64
#   start_time: 32.0
#   end_time: 32.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 32.25
#   end_time: 32.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 32.5
#   end_time: 33.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 62
#   velocity: 64
#   start_time: 33.0
#   end_time: 33.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 33.25
#   end_time: 33.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 58
#   velocity: 64
#   start_time: 33.5
#   end_time: 34.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 34.0
#   end_time: 34.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 34.5
#   end_time: 35.5
#   numerator: 1
#   denominator: 2
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 35.5
#   end_time: 35.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 35.75
#   end_time: 36.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 36.0
#   end_time: 36.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 46
#   velocity: 64
#   start_time: 36.5
#   end_time: 36.75
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 36.75
#   end_time: 37.0
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 53
#   velocity: 64
#   start_time: 37.0
#   end_time: 37.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 55
#   velocity: 64
#   start_time: 37.5
#   end_time: 38.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 57
#   velocity: 64
#   start_time: 38.0
#   end_time: 38.25
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 50
#   velocity: 64
#   start_time: 38.25
#   end_time: 38.5
#   numerator: 1
#   denominator: 8
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 47
#   velocity: 64
#   start_time: 38.5
#   end_time: 39.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 48
#   velocity: 64
#   start_time: 39.0
#   end_time: 39.5
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# notes {
#   pitch: 41
#   velocity: 64
#   start_time: 39.5
#   end_time: 40.0
#   numerator: 1
#   denominator: 4
#   instrument: 4
#   program: 1
#   part: 4
#   voice: 1
# }
# total_time: 40.0
# part_infos {
#   name: "Horn 2"
# }
# part_infos {
#   part: 1
#   name: "Soprano"
# }
# part_infos {
#   part: 2
#   name: "Alto"
# }
# part_infos {
#   part: 3
#   name: "Tenor"
# }
# part_infos {
#   part: 4
#   name: "Bass"
# }
# source_info {
#   source_type: SCORE_BASED
#   encoding_type: MUSIC_XML
#   parser: MAGENTA_MUSIC_XML
# }

# %% [markdown]
# 从上面我们可以看到这里面包含了路径、id、以及xml中的内容。大部分应该是直接从xml中直接转换而来，但将它们分成类结构化储存了。
#
# 于是，我们也可以直接访问它的子类

# %%
print(sequence_xml.id)
print(sequence_xml.filename)
# Out:
# /id/musicxml/xml_raw/efab6353dd5ebf096204bc6316d1d2f003b156c7
# E:\Magenta\Dataset\xml_raw\bwv1.6.mxl

# %%
print(type(sequence_xml.notes))
# Out:
# <class 'google.protobuf.pyext._message.RepeatedCompositeContainer'>

# %% [markdown]
# sequence_xml的note类里面就是最主要的内容了，主要记录了所有的音符。
# 音符类当然也支持索引，我们可以看到每个音符由音高、音色、起始时间、终止时间等组成。

# %%
print(sequence_xml.notes[0])
# Out:
# pitch: 65
# velocity: 64
# end_time: 0.5
# numerator: 1
# denominator: 4
# instrument: 7
# program: 1
# voice: 1

# %% [markdown]
# 我用MuseScore2将XML导出为midi后进行下面的测试：

# %%
full_file_path_midi=r'E:\Magenta\Midi\bwv1.6.mid'
root_dir_midi=r'E:\Magenta\Midi'
sub_dir_midi=r'E:\Magenta\Midi'
sequence_midi=cvrt.convert_midi(root_dir_midi, sub_dir_midi, full_file_path_midi)
# Out:
# INFO:tensorflow:Converted MIDI file E:\Magenta\Midi\bwv1.6.mid.
# D:\Anaconda3\envs\tensorflow\lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)

# %% [markdown]
# 我们看到，MIDI形式的储存格式和XML大同小异，但是起始和终止的时间看起来很乱。

# %%
print(sequence_midi)
# Out:
# id: "/id/midi/Midi/3178bdc5f3b8046f53bf1e8cf618d765620a1c74"
# filename: "E:\\Magenta\\Midi\\bwv1.6.mid"
# collection_name: "Midi"
# ticks_per_quarter: 480
# time_signatures {
#   numerator: 1
#   denominator: 4
# }
# time_signatures {
#   time: 0.789474
#   numerator: 4
#   denominator: 4
# }
# time_signatures {
#   time: 60.789498
#   numerator: 3
#   denominator: 4
# }
# key_signatures {
#   key: F
# }
# tempos {
#   qpm: 75.99996960001216
# }
# notes {
#   pitch: 65
#   velocity: 80
#   end_time: 0.7878292625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 0.789474
#   end_time: 1.1825662625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 1.184211
#   end_time: 1.5773032625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 1.578948
#   end_time: 1.9720402625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 1.9736850000000001
#   end_time: 2.3667772625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 2.368422
#   end_time: 2.7615142625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 2.763159
#   end_time: 3.1562512625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 3.157896
#   end_time: 3.5509882625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 3.552633
#   end_time: 3.9457252625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 3.9473700000000003
#   end_time: 4.1430937625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 4.1447385
#   end_time: 4.3404622625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 4.342107
#   end_time: 4.5378307625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 4.5394755
#   end_time: 4.7351992625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 4.736844
#   end_time: 5.1299362625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 5.131581
#   end_time: 5.5246732625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 5.526318
#   end_time: 6.3141472625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 6.315792
#   end_time: 7.1036212625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 7.105266
#   end_time: 7.4983582625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 7.500003
#   end_time: 7.6957267625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 7.6973715
#   end_time: 7.8930952625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 7.8947400000000005
#   end_time: 8.2878322625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 8.289477
#   end_time: 8.4852007625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 8.4868455
#   end_time: 8.6825692625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 8.684214
#   end_time: 9.0773062625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 9.078951
#   end_time: 9.4720432625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 9.473688
#   end_time: 9.8667802625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 9.868425
#   end_time: 10.2615172625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 10.263162
#   end_time: 10.656254262500001
# }
# notes {
#   pitch: 71
#   velocity: 80
#   start_time: 10.657899
#   end_time: 10.8536227625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 10.8552675
#   end_time: 11.0509912625
# }
# notes {
#   pitch: 71
#   velocity: 80
#   start_time: 11.052636
#   end_time: 11.8404652625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 11.84211
#   end_time: 12.6299392625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 12.631584
#   end_time: 13.8141502625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 13.815795
#   end_time: 14.2088872625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 14.210532
#   end_time: 14.6036242625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 14.605269
#   end_time: 14.9983612625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 15.000006
#   end_time: 15.3930982625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 15.394743
#   end_time: 15.7878352625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 15.789480000000001
#   end_time: 16.1825722625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 16.184217
#   end_time: 16.577309262500002
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 16.578954
#   end_time: 16.9720462625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 16.973691
#   end_time: 17.1694147625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 17.171059500000002
#   end_time: 17.3667832625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 17.368428
#   end_time: 17.7615202625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 17.763165
#   end_time: 17.9588887625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 17.9605335
#   end_time: 18.1562572625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 18.157902
#   end_time: 18.9457312625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 18.947376
#   end_time: 19.7352052625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 19.73685
#   end_time: 20.129942262500002
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 20.131587
#   end_time: 20.5246792625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 20.526324
#   end_time: 20.9194162625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 20.921061
#   end_time: 21.3141532625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 21.315798
#   end_time: 21.7088902625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 21.710535
#   end_time: 22.1036272625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 22.105272
#   end_time: 22.4983642625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 22.500009
#   end_time: 22.8931012625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 22.894746
#   end_time: 23.0904697625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 23.0921145
#   end_time: 23.2878382625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 23.289483
#   end_time: 23.4852067625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 23.4868515
#   end_time: 23.6825752625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 23.68422
#   end_time: 24.0773122625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 24.078957
#   end_time: 24.4720492625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 24.473694000000002
#   end_time: 25.2615232625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 25.263168
#   end_time: 26.0509972625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 26.052642
#   end_time: 26.4457342625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 26.447379
#   end_time: 26.6431027625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 26.6447475
#   end_time: 26.8404712625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 26.842116
#   end_time: 27.2352082625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 27.236853
#   end_time: 27.432576762500002
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 27.4342215
#   end_time: 27.6299452625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 27.63159
#   end_time: 28.0246822625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 28.026327000000002
#   end_time: 28.4194192625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 28.421064
#   end_time: 28.8141562625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 28.815801
#   end_time: 29.208893262500002
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 29.210538
#   end_time: 29.6036302625
# }
# notes {
#   pitch: 71
#   velocity: 80
#   start_time: 29.605275
#   end_time: 29.8009987625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 29.802643500000002
#   end_time: 29.9983672625
# }
# notes {
#   pitch: 71
#   velocity: 80
#   start_time: 30.000012
#   end_time: 30.7878412625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 30.789486
#   end_time: 31.5773152625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 31.578960000000002
#   end_time: 32.7615262625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 32.763171
#   end_time: 33.1562632625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 33.157908
#   end_time: 33.5510002625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 33.552645
#   end_time: 33.9457372625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 33.947382
#   end_time: 34.3404742625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 34.342119000000004
#   end_time: 34.7352112625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 34.736856
#   end_time: 35.1299482625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 35.131593
#   end_time: 35.5246852625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 35.52633
#   end_time: 35.9194222625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 35.921067
#   end_time: 36.1167907625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 36.118435500000004
#   end_time: 36.3141592625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 36.315804
#   end_time: 36.7088962625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 36.710541
#   end_time: 36.9062647625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 36.9079095
#   end_time: 37.1036332625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 37.105278
#   end_time: 37.8931072625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 38.684226
#   end_time: 39.0773182625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 39.078963
#   end_time: 39.274686762500004
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 39.2763315
#   end_time: 39.4720552625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 39.4737
#   end_time: 39.6694237625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 39.6710685
#   end_time: 39.8667922625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 39.868437
#   end_time: 40.0641607625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 40.0658055
#   end_time: 40.2615292625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 40.263174
#   end_time: 41.8404772625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 41.842122
#   end_time: 42.0378457625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 42.0394905
#   end_time: 42.2352142625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 42.236859
#   end_time: 42.4325827625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 42.4342275
#   end_time: 42.6299512625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 42.631596
#   end_time: 43.4194252625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 43.42107
#   end_time: 44.9983732625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 45.000018
#   end_time: 45.3931102625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 45.394755
#   end_time: 45.7878472625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 45.789492
#   end_time: 46.1825842625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 46.184229
#   end_time: 46.5773212625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 46.578966
#   end_time: 46.9720582625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 46.973703
#   end_time: 47.1694267625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 47.171071500000004
#   end_time: 47.3667952625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 47.36844
#   end_time: 47.7615322625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 47.763177
#   end_time: 47.9589007625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 47.9605455
#   end_time: 48.156269262500004
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 48.157914
#   end_time: 48.5510062625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 48.552651
#   end_time: 48.9457432625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 48.947388000000004
#   end_time: 49.3404802625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 49.342125
#   end_time: 49.7352172625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 49.736862
#   end_time: 50.9194282625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 50.921073
#   end_time: 51.3141652625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 51.31581
#   end_time: 51.708902262500004
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 51.710547
#   end_time: 51.9062707625
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 51.9079155
#   end_time: 52.1036392625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 52.105284
#   end_time: 53.2878502625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 53.289495
#   end_time: 53.6825872625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 53.684232
#   end_time: 54.0773242625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 54.078969
#   end_time: 54.2746927625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 54.276337500000004
#   end_time: 54.4720612625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 54.473706
#   end_time: 56.0510092625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 56.052654000000004
#   end_time: 56.2483777625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 56.2500225
#   end_time: 56.4457462625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 56.447391
#   end_time: 56.6431147625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 56.6447595
#   end_time: 56.8404832625
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 56.842128
#   end_time: 58.0246942625
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 58.026339
#   end_time: 58.8141682625
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 58.815813
#   end_time: 59.6036422625
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 59.605287000000004
#   end_time: 60.3931162625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 60.394761
#   end_time: 61.1825902625
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 61.184235
#   end_time: 61.5773272625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 61.578972
#   end_time: 61.9720642625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 61.973709
#   end_time: 62.1694327625
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 62.1710775
#   end_time: 62.3668012625
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 62.368446
#   end_time: 63.1562752625
# }
# notes {
#   pitch: 65
#   velocity: 80
#   end_time: 0.7878292625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 0.789474
#   end_time: 1.5773032625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 1.578948
#   end_time: 2.3667772625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 2.368422
#   end_time: 3.1562512625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 3.157896
#   end_time: 3.9457252625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 3.9473700000000003
#   end_time: 4.7351992625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 4.736844
#   end_time: 5.5246732625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 5.526318
#   end_time: 6.3141472625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 6.315792
#   end_time: 7.1036212625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 7.105266
#   end_time: 7.8930952625
#   instrument: 1
# }
# notes {
#   pitch: 76
#   velocity: 80
#   start_time: 7.8947400000000005
#   end_time: 8.6825692625
#   instrument: 1
# }
# notes {
#   pitch: 77
#   velocity: 80
#   start_time: 8.684214
#   end_time: 9.4720432625
#   instrument: 1
# }
# notes {
#   pitch: 76
#   velocity: 80
#   start_time: 9.473688
#   end_time: 10.2615172625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 10.263162
#   end_time: 11.0509912625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 11.052636
#   end_time: 11.8404652625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 11.84211
#   end_time: 12.6299392625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 12.631584
#   end_time: 13.4194132625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 13.421058
#   end_time: 14.2088872625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 14.210532
#   end_time: 14.9983612625
#   instrument: 1
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 15.000006
#   end_time: 15.7878352625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 15.789480000000001
#   end_time: 16.577309262500002
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 16.578954
#   end_time: 18.1562572625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 18.157902
#   end_time: 18.9457312625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 18.947376
#   end_time: 19.7352052625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 19.73685
#   end_time: 20.5246792625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 20.526324
#   end_time: 21.3141532625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 21.315798
#   end_time: 22.1036272625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 22.105272
#   end_time: 22.8931012625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 22.894746
#   end_time: 23.6825752625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 23.68422
#   end_time: 24.4720492625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 24.473694000000002
#   end_time: 25.2615232625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 25.263168
#   end_time: 26.0509972625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 26.052642
#   end_time: 26.8404712625
#   instrument: 1
# }
# notes {
#   pitch: 76
#   velocity: 80
#   start_time: 26.842116
#   end_time: 27.6299452625
#   instrument: 1
# }
# notes {
#   pitch: 77
#   velocity: 80
#   start_time: 27.63159
#   end_time: 28.4194192625
#   instrument: 1
# }
# notes {
#   pitch: 76
#   velocity: 80
#   start_time: 28.421064
#   end_time: 29.208893262500002
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 29.210538
#   end_time: 29.9983672625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 30.000012
#   end_time: 30.7878412625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 30.789486
#   end_time: 31.5773152625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 31.578960000000002
#   end_time: 32.3667892625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 32.368434
#   end_time: 33.1562632625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 33.157908
#   end_time: 33.9457372625
#   instrument: 1
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 33.947382
#   end_time: 34.7352112625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 34.736856
#   end_time: 35.5246852625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 35.52633
#   end_time: 37.1036332625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 37.105278
#   end_time: 37.8931072625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 38.684226
#   end_time: 40.2615292625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 40.263174
#   end_time: 41.8404772625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 41.842122
#   end_time: 43.4194252625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 43.42107
#   end_time: 44.9983732625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 45.000018
#   end_time: 45.7878472625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 45.789492
#   end_time: 46.5773212625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 46.578966
#   end_time: 47.3667952625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 47.36844
#   end_time: 48.156269262500004
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 48.157914
#   end_time: 48.9457432625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 48.947388000000004
#   end_time: 49.7352172625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 49.736862
#   end_time: 50.5246912625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 50.526336
#   end_time: 51.3141652625
#   instrument: 1
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 51.31581
#   end_time: 52.1036392625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 52.105284
#   end_time: 52.8931132625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 52.894758
#   end_time: 54.4720612625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 54.473706
#   end_time: 56.0510092625
#   instrument: 1
# }
# notes {
#   pitch: 77
#   velocity: 80
#   start_time: 56.052654000000004
#   end_time: 56.8404832625
#   instrument: 1
# }
# notes {
#   pitch: 76
#   velocity: 80
#   start_time: 56.842128
#   end_time: 57.6299572625
#   instrument: 1
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 57.631602
#   end_time: 58.4194312625
#   instrument: 1
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 58.421076
#   end_time: 59.208905262500004
#   instrument: 1
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 59.21055
#   end_time: 59.9983792625
#   instrument: 1
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 60.000024
#   end_time: 60.7878532625
#   instrument: 1
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 60.789498
#   end_time: 62.3668012625
#   instrument: 1
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 62.368446
#   end_time: 63.1562752625
#   instrument: 1
# }
# notes {
#   pitch: 60
#   velocity: 80
#   end_time: 0.7878292625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 0.789474
#   end_time: 1.5773032625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 1.578948
#   end_time: 2.3667772625
#   instrument: 2
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 2.368422
#   end_time: 3.1562512625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 3.157896
#   end_time: 3.9457252625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 3.9473700000000003
#   end_time: 4.7351992625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 4.736844
#   end_time: 5.5246732625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 5.526318
#   end_time: 6.3141472625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 6.315792
#   end_time: 7.1036212625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 7.105266
#   end_time: 7.8930952625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 7.8947400000000005
#   end_time: 8.6825692625
#   instrument: 2
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 8.684214
#   end_time: 9.0773062625
#   instrument: 2
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 9.078951
#   end_time: 9.4720432625
#   instrument: 2
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 9.473688
#   end_time: 9.8667802625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 9.868425
#   end_time: 10.2615172625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 10.263162
#   end_time: 11.0509912625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 11.052636
#   end_time: 11.8404652625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 11.84211
#   end_time: 12.6299392625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 12.631584
#   end_time: 13.4194132625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 13.421058
#   end_time: 14.2088872625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 14.210532
#   end_time: 14.9983612625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 15.000006
#   end_time: 15.3930982625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 15.394743
#   end_time: 15.7878352625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 15.789480000000001
#   end_time: 16.1825722625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 16.184217
#   end_time: 16.577309262500002
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 16.578954
#   end_time: 17.3667832625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 17.368428
#   end_time: 18.1562572625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 18.157902
#   end_time: 18.9457312625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 18.947376
#   end_time: 19.7352052625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 19.73685
#   end_time: 20.5246792625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 20.526324
#   end_time: 21.3141532625
#   instrument: 2
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 21.315798
#   end_time: 22.1036272625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 22.105272
#   end_time: 22.8931012625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 22.894746
#   end_time: 23.6825752625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 23.68422
#   end_time: 24.4720492625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 24.473694000000002
#   end_time: 25.2615232625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 25.263168
#   end_time: 26.0509972625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 26.052642
#   end_time: 26.8404712625
#   instrument: 2
# }
# notes {
#   pitch: 70
#   velocity: 80
#   start_time: 26.842116
#   end_time: 27.6299452625
#   instrument: 2
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 27.63159
#   end_time: 28.0246822625
#   instrument: 2
# }
# notes {
#   pitch: 74
#   velocity: 80
#   start_time: 28.026327000000002
#   end_time: 28.4194192625
#   instrument: 2
# }
# notes {
#   pitch: 72
#   velocity: 80
#   start_time: 28.421064
#   end_time: 28.8141562625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 28.815801
#   end_time: 29.208893262500002
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 29.210538
#   end_time: 29.9983672625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 30.000012
#   end_time: 30.7878412625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 30.789486
#   end_time: 31.5773152625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 31.578960000000002
#   end_time: 32.3667892625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 32.368434
#   end_time: 33.1562632625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 33.157908
#   end_time: 33.9457372625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 33.947382
#   end_time: 34.3404742625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 34.342119000000004
#   end_time: 34.7352112625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 34.736856
#   end_time: 35.1299482625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 35.131593
#   end_time: 35.5246852625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 35.52633
#   end_time: 36.3141592625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 36.315804
#   end_time: 37.1036332625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 37.105278
#   end_time: 37.8931072625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 38.684226
#   end_time: 40.2615292625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 40.263174
#   end_time: 41.8404772625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 41.842122
#   end_time: 42.2352142625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 42.236859
#   end_time: 42.4325827625
#   instrument: 2
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 42.4342275
#   end_time: 42.6299512625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 42.631596
#   end_time: 43.4194252625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 43.42107
#   end_time: 44.9983732625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 45.000018
#   end_time: 45.7878472625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 45.789492
#   end_time: 46.5773212625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 46.578966
#   end_time: 47.3667952625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 47.36844
#   end_time: 48.156269262500004
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 48.157914
#   end_time: 48.9457432625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 48.947388000000004
#   end_time: 49.7352172625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 49.736862
#   end_time: 50.5246912625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 50.526336
#   end_time: 51.3141652625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 51.31581
#   end_time: 52.1036392625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 52.105284
#   end_time: 52.4983762625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 52.500021000000004
#   end_time: 52.8931132625
#   instrument: 2
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 52.894758
#   end_time: 53.6825872625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 53.684232
#   end_time: 54.4720612625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 54.473706
#   end_time: 56.0510092625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 56.052654000000004
#   end_time: 56.8404832625
#   instrument: 2
# }
# notes {
#   pitch: 69
#   velocity: 80
#   start_time: 56.842128
#   end_time: 57.2352202625
#   instrument: 2
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 57.236865
#   end_time: 57.6299572625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 57.631602
#   end_time: 58.4194312625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 58.421076
#   end_time: 59.208905262500004
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 59.21055
#   end_time: 59.6036422625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 59.605287000000004
#   end_time: 59.9983792625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 60.000024
#   end_time: 60.3931162625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 60.394761
#   end_time: 60.7878532625
#   instrument: 2
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 60.789498
#   end_time: 61.5773272625
#   instrument: 2
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 61.578972
#   end_time: 62.3668012625
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 62.368446
#   end_time: 63.1562752625
#   instrument: 2
# }
# notes {
#   pitch: 57
#   velocity: 80
#   end_time: 0.7878292625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 0.789474
#   end_time: 1.5773032625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 1.578948
#   end_time: 2.3667772625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 2.368422
#   end_time: 3.1562512625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 3.157896
#   end_time: 3.9457252625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 3.9473700000000003
#   end_time: 4.7351992625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 4.736844
#   end_time: 5.5246732625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 5.526318
#   end_time: 6.3141472625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 6.315792
#   end_time: 7.1036212625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 7.105266
#   end_time: 7.8930952625
#   instrument: 3
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 7.8947400000000005
#   end_time: 8.6825692625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 8.684214
#   end_time: 9.0773062625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 9.078951
#   end_time: 9.4720432625
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 9.473688
#   end_time: 10.2615172625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 10.263162
#   end_time: 10.656254262500001
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 10.657899
#   end_time: 11.0509912625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 11.052636
#   end_time: 11.8404652625
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 11.84211
#   end_time: 12.6299392625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 12.631584
#   end_time: 13.0246762625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 13.026321
#   end_time: 13.4194132625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 13.421058
#   end_time: 13.8141502625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 13.815795
#   end_time: 14.2088872625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 14.210532
#   end_time: 14.9983612625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 15.000006
#   end_time: 15.3930982625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 15.394743
#   end_time: 15.7878352625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 15.789480000000001
#   end_time: 16.1825722625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 16.184217
#   end_time: 16.577309262500002
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 16.578954
#   end_time: 16.9720462625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 16.973691
#   end_time: 17.3667832625
#   instrument: 3
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 17.368428
#   end_time: 18.1562572625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 18.157902
#   end_time: 18.9457312625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 18.947376
#   end_time: 19.7352052625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 19.73685
#   end_time: 20.5246792625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 20.526324
#   end_time: 21.3141532625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 21.315798
#   end_time: 22.1036272625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 22.105272
#   end_time: 22.8931012625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 22.894746
#   end_time: 23.6825752625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 23.68422
#   end_time: 24.4720492625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 24.473694000000002
#   end_time: 25.2615232625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 25.263168
#   end_time: 26.0509972625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 26.052642
#   end_time: 26.8404712625
#   instrument: 3
# }
# notes {
#   pitch: 67
#   velocity: 80
#   start_time: 26.842116
#   end_time: 27.6299452625
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 27.63159
#   end_time: 28.0246822625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 28.026327000000002
#   end_time: 28.4194192625
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 28.421064
#   end_time: 29.208893262500002
#   instrument: 3
# }
# notes {
#   pitch: 65
#   velocity: 80
#   start_time: 29.210538
#   end_time: 29.6036302625
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 29.605275
#   end_time: 29.9983672625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 30.000012
#   end_time: 30.7878412625
#   instrument: 3
# }
# notes {
#   pitch: 64
#   velocity: 80
#   start_time: 30.789486
#   end_time: 31.5773152625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 31.578960000000002
#   end_time: 31.9720522625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 31.973697
#   end_time: 32.3667892625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 32.368434
#   end_time: 32.7615262625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 32.763171
#   end_time: 33.1562632625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 33.157908
#   end_time: 34.3404742625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 34.342119000000004
#   end_time: 34.7352112625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 34.736856
#   end_time: 35.1299482625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 35.131593
#   end_time: 35.5246852625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 35.52633
#   end_time: 35.9194222625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 35.921067
#   end_time: 36.3141592625
#   instrument: 3
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 36.315804
#   end_time: 37.1036332625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 37.105278
#   end_time: 37.8931072625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 38.684226
#   end_time: 40.2615292625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 40.263174
#   end_time: 41.8404772625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 41.842122
#   end_time: 43.4194252625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 43.42107
#   end_time: 44.9983732625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 45.000018
#   end_time: 45.7878472625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 45.789492
#   end_time: 46.5773212625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 46.578966
#   end_time: 47.3667952625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 47.36844
#   end_time: 48.156269262500004
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 48.157914
#   end_time: 48.9457432625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 48.947388000000004
#   end_time: 49.7352172625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 49.736862
#   end_time: 50.5246912625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 50.526336
#   end_time: 51.3141652625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 51.31581
#   end_time: 52.1036392625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 52.105284
#   end_time: 52.8931132625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 52.894758
#   end_time: 53.6825872625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 53.684232
#   end_time: 54.4720612625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 54.473706
#   end_time: 56.0510092625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 56.052654000000004
#   end_time: 56.8404832625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 56.842128
#   end_time: 57.6299572625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 57.631602
#   end_time: 58.0246942625
#   instrument: 3
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 58.026339
#   end_time: 58.4194312625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 58.421076
#   end_time: 58.8141682625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 58.815813
#   end_time: 59.208905262500004
#   instrument: 3
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 59.21055
#   end_time: 59.9983792625
#   instrument: 3
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 60.000024
#   end_time: 60.3931162625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 60.394761
#   end_time: 60.7878532625
#   instrument: 3
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 60.789498
#   end_time: 61.5773272625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 61.578972
#   end_time: 61.7746957625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 61.7763405
#   end_time: 61.9720642625
#   instrument: 3
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 61.973709
#   end_time: 62.3668012625
#   instrument: 3
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 62.368446
#   end_time: 63.1562752625
#   instrument: 3
# }
# notes {
#   pitch: 53
#   velocity: 80
#   end_time: 0.7878292625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 0.789474
#   end_time: 1.5773032625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 1.578948
#   end_time: 2.3667772625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 2.368422
#   end_time: 3.1562512625
#   instrument: 4
# }
# notes {
#   pitch: 45
#   velocity: 80
#   start_time: 3.157896
#   end_time: 3.9457252625
#   instrument: 4
# }
# notes {
#   pitch: 46
#   velocity: 80
#   start_time: 3.9473700000000003
#   end_time: 4.3404622625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 4.342107
#   end_time: 4.7351992625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 4.736844
#   end_time: 5.1299362625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 5.131581
#   end_time: 5.5246732625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 5.526318
#   end_time: 6.3141472625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 6.315792
#   end_time: 7.1036212625
#   instrument: 4
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 7.105266
#   end_time: 7.8930952625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 7.8947400000000005
#   end_time: 8.2878322625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 8.289477
#   end_time: 8.6825692625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 8.684214
#   end_time: 9.0773062625
#   instrument: 4
# }
# notes {
#   pitch: 59
#   velocity: 80
#   start_time: 9.078951
#   end_time: 9.4720432625
#   instrument: 4
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 9.473688
#   end_time: 10.2615172625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 10.263162
#   end_time: 11.0509912625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 11.052636
#   end_time: 11.8404652625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 11.84211
#   end_time: 12.6299392625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 12.631584
#   end_time: 13.4194132625
#   instrument: 4
# }
# notes {
#   pitch: 46
#   velocity: 80
#   start_time: 13.421058
#   end_time: 14.2088872625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 14.210532
#   end_time: 14.9983612625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 15.000006
#   end_time: 15.3930982625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 15.394743
#   end_time: 15.7878352625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 15.789480000000001
#   end_time: 16.577309262500002
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 16.578954
#   end_time: 18.1562572625
#   instrument: 4
# }
# notes {
#   pitch: 41
#   velocity: 80
#   start_time: 18.157902
#   end_time: 18.9457312625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 18.947376
#   end_time: 19.7352052625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 19.73685
#   end_time: 20.5246792625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 20.526324
#   end_time: 21.3141532625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 21.315798
#   end_time: 22.1036272625
#   instrument: 4
# }
# notes {
#   pitch: 45
#   velocity: 80
#   start_time: 22.105272
#   end_time: 22.8931012625
#   instrument: 4
# }
# notes {
#   pitch: 46
#   velocity: 80
#   start_time: 22.894746
#   end_time: 23.2878382625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 23.289483
#   end_time: 23.6825752625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 23.68422
#   end_time: 24.0773122625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 24.078957
#   end_time: 24.4720492625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 24.473694000000002
#   end_time: 25.2615232625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 25.263168
#   end_time: 26.0509972625
#   instrument: 4
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 26.052642
#   end_time: 26.8404712625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 26.842116
#   end_time: 27.2352082625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 27.236853
#   end_time: 27.6299452625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 27.63159
#   end_time: 28.0246822625
#   instrument: 4
# }
# notes {
#   pitch: 59
#   velocity: 80
#   start_time: 28.026327000000002
#   end_time: 28.4194192625
#   instrument: 4
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 28.421064
#   end_time: 29.208893262500002
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 29.210538
#   end_time: 29.9983672625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 30.000012
#   end_time: 30.7878412625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 30.789486
#   end_time: 31.5773152625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 31.578960000000002
#   end_time: 32.3667892625
#   instrument: 4
# }
# notes {
#   pitch: 46
#   velocity: 80
#   start_time: 32.368434
#   end_time: 33.1562632625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 33.157908
#   end_time: 33.9457372625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 33.947382
#   end_time: 34.3404742625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 34.342119000000004
#   end_time: 34.7352112625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 34.736856
#   end_time: 35.5246852625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 35.52633
#   end_time: 37.1036332625
#   instrument: 4
# }
# notes {
#   pitch: 41
#   velocity: 80
#   start_time: 37.105278
#   end_time: 37.8931072625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 38.684226
#   end_time: 40.2615292625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 40.263174
#   end_time: 41.8404772625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 41.842122
#   end_time: 43.4194252625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 43.42107
#   end_time: 44.9983732625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 45.000018
#   end_time: 45.3931102625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 45.394755
#   end_time: 45.7878472625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 45.789492
#   end_time: 46.1825842625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 46.184229
#   end_time: 46.5773212625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 46.578966
#   end_time: 46.9720582625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 46.973703
#   end_time: 47.3667952625
#   instrument: 4
# }
# notes {
#   pitch: 52
#   velocity: 80
#   start_time: 47.36844
#   end_time: 47.7615322625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 47.763177
#   end_time: 48.156269262500004
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 48.157914
#   end_time: 48.5510062625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 48.552651
#   end_time: 48.9457432625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 48.947388000000004
#   end_time: 49.3404802625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 49.342125
#   end_time: 49.7352172625
#   instrument: 4
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 49.736862
#   end_time: 50.5246912625
#   instrument: 4
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 50.526336
#   end_time: 50.9194282625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 50.921073
#   end_time: 51.3141652625
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 51.31581
#   end_time: 52.1036392625
#   instrument: 4
# }
# notes {
#   pitch: 62
#   velocity: 80
#   start_time: 52.105284
#   end_time: 52.4983762625
#   instrument: 4
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 52.500021000000004
#   end_time: 52.8931132625
#   instrument: 4
# }
# notes {
#   pitch: 58
#   velocity: 80
#   start_time: 52.894758
#   end_time: 53.6825872625
#   instrument: 4
# }
# notes {
#   pitch: 60
#   velocity: 80
#   start_time: 53.684232
#   end_time: 54.4720612625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 54.473706
#   end_time: 56.0510092625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 56.052654000000004
#   end_time: 56.4457462625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 56.447391
#   end_time: 56.8404832625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 56.842128
#   end_time: 57.6299572625
#   instrument: 4
# }
# notes {
#   pitch: 46
#   velocity: 80
#   start_time: 57.631602
#   end_time: 58.0246942625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 58.026339
#   end_time: 58.4194312625
#   instrument: 4
# }
# notes {
#   pitch: 53
#   velocity: 80
#   start_time: 58.421076
#   end_time: 59.208905262500004
#   instrument: 4
# }
# notes {
#   pitch: 55
#   velocity: 80
#   start_time: 59.21055
#   end_time: 59.9983792625
#   instrument: 4
# }
# notes {
#   pitch: 57
#   velocity: 80
#   start_time: 60.000024
#   end_time: 60.3931162625
#   instrument: 4
# }
# notes {
#   pitch: 50
#   velocity: 80
#   start_time: 60.394761
#   end_time: 60.7878532625
#   instrument: 4
# }
# notes {
#   pitch: 47
#   velocity: 80
#   start_time: 60.789498
#   end_time: 61.5773272625
#   instrument: 4
# }
# notes {
#   pitch: 48
#   velocity: 80
#   start_time: 61.578972
#   end_time: 62.3668012625
#   instrument: 4
# }
# notes {
#   pitch: 41
#   velocity: 80
#   start_time: 62.368446
#   end_time: 63.1562752625
#   instrument: 4
# }
# total_time: 63.1562752625
# control_changes {
#   control_number: 121
# }
# control_changes {
#   control_number: 7
#   control_value: 100
# }
# control_changes {
#   control_number: 10
#   control_value: 63
# }
# control_changes {
#   control_number: 91
# }
# control_changes {
#   control_number: 93
# }
# control_changes {
#   control_number: 121
#   instrument: 1
# }
# control_changes {
#   control_number: 7
#   control_value: 100
#   instrument: 1
# }
# control_changes {
#   control_number: 10
#   control_value: 63
#   instrument: 1
# }
# control_changes {
#   control_number: 91
#   instrument: 1
# }
# control_changes {
#   control_number: 93
#   instrument: 1
# }
# control_changes {
#   control_number: 121
#   instrument: 2
# }
# control_changes {
#   control_number: 7
#   control_value: 100
#   instrument: 2
# }
# control_changes {
#   control_number: 10
#   control_value: 63
#   instrument: 2
# }
# control_changes {
#   control_number: 91
#   instrument: 2
# }
# control_changes {
#   control_number: 93
#   instrument: 2
# }
# control_changes {
#   control_number: 121
#   instrument: 3
# }
# control_changes {
#   control_number: 7
#   control_value: 100
#   instrument: 3
# }
# control_changes {
#   control_number: 10
#   control_value: 63
#   instrument: 3
# }
# control_changes {
#   control_number: 91
#   instrument: 3
# }
# control_changes {
#   control_number: 93
#   instrument: 3
# }
# control_changes {
#   control_number: 121
#   instrument: 4
# }
# control_changes {
#   control_number: 7
#   control_value: 100
#   instrument: 4
# }
# control_changes {
#   control_number: 10
#   control_value: 63
#   instrument: 4
# }
# control_changes {
#   control_number: 91
#   instrument: 4
# }
# control_changes {
#   control_number: 93
#   instrument: 4
# }
# source_info {
#   encoding_type: MIDI
#   parser: PRETTY_MIDI
# }

# %%
print(type(sequence_midi.notes))
# Out:
# <class 'google.protobuf.pyext._message.RepeatedCompositeContainer'>

# %%
print(sequence_midi.notes[0])
print(sequence_midi.notes[1])
print(sequence_midi.notes[288])
# Out:
# pitch: 65
# velocity: 80
# end_time: 0.7878292625
#
# pitch: 67
# velocity: 80
# start_time: 0.789474
# end_time: 1.1825662625
#
# pitch: 67
# velocity: 80
# start_time: 51.31581
# end_time: 52.1036392625
# instrument: 2

# %% [markdown]
# 我们可以看到，MIDI的Notes里面的内容就相对简单了。而且似乎格式也不太整齐。这有可能是由于我转换的方式不够好。

# %%
full_file_path_midi=r'E:\Magenta\Midi\Bwv0525 Sonate en trio n1.mid'
root_dir_midi=r'E:\Magenta\Midi'
sub_dir_midi=r'E:\Magenta\Midi'
sequence_midi=cvrt.convert_midi(root_dir_midi, sub_dir_midi, full_file_path_midi)
# Out:
# INFO:tensorflow:Converted MIDI file E:\Magenta\Midi\Bwv0525 Sonate en trio n1.mid.

# %%
print(sequence_midi)
# Out:
# id: "/id/midi/Midi/2cf7dfe24ee27ef1a49f6158b0c5c303b2bbf807"
# filename: "E:\\Magenta\\Midi\\Bwv0525 Sonate en trio n1.mid"
# collection_name: "Midi"
# ticks_per_quarter: 480
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# time_signatures {
#   time: 187.07416394583333
#   numerator: 12
#   denominator: 8
# }
# time_signatures {
#   time: 562.6120114458334
#   numerator: 3
#   denominator: 4
# }
# tempos {
#   qpm: 75.0
# }
# tempos {
#   time: 179.20000000000002
#   qpm: 70.00007000007
# }
# tempos {
#   time: 182.62856800000003
#   qpm: 65.000065000065
# }
# tempos {
#   time: 184.47472000000002
#   qpm: 50.0
# }
# tempos {
#   time: 185.07972
#   qpm: 45.000011250002814
# }
# tempos {
#   time: 187.07416394583333
#   qpm: 120.0
# }
# tempos {
#   time: 189.32416394583333
#   qpm: 55.000004583333705
# }
# tempos {
#   time: 554.7786789458335
#   qpm: 45.000011250002814
# }
# tempos {
#   time: 558.1120114458334
#   qpm: 80.0
# }
# tempos {
#   time: 848.3620114458334
#   qpm: 50.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 6.4
#   end_time: 6.800000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 6.800000000000001
#   end_time: 7.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 7.2
#   end_time: 8.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 8.0
#   end_time: 8.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 8.4
#   end_time: 8.8
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 8.8
#   end_time: 9.8
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 9.8
#   end_time: 10.0
# }
# notes {
#   pitch: 81
#   velocity: 92
#   start_time: 10.0
#   end_time: 10.200000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 10.200000000000001
#   end_time: 10.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 10.4
#   end_time: 10.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 10.8
#   end_time: 10.9
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 10.9
#   end_time: 11.0
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 11.0
#   end_time: 11.200000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 11.200000000000001
#   end_time: 11.600000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 11.600000000000001
#   end_time: 11.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 11.8
#   end_time: 12.0
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 12.0
#   end_time: 12.200000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 12.200000000000001
#   end_time: 12.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 12.4
#   end_time: 12.600000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 12.600000000000001
#   end_time: 12.8
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 12.8
#   end_time: 13.200000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 13.200000000000001
#   end_time: 13.600000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 13.600000000000001
#   end_time: 14.600000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 14.600000000000001
#   end_time: 14.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 14.8
#   end_time: 15.000000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 15.000000000000002
#   end_time: 15.200000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 15.200000000000001
#   end_time: 15.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 15.4
#   end_time: 15.600000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 15.600000000000001
#   end_time: 15.8
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 15.8
#   end_time: 16.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 16.0
#   end_time: 16.400000000000002
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 16.400000000000002
#   end_time: 16.8
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 16.8
#   end_time: 18.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 18.0
#   end_time: 18.400000000000002
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 18.400000000000002
#   end_time: 18.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 18.6
#   end_time: 18.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 18.8
#   end_time: 19.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 19.6
#   end_time: 20.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 20.0
#   end_time: 20.200000000000003
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 20.200000000000003
#   end_time: 20.400000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 20.400000000000002
#   end_time: 21.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 21.0
#   end_time: 21.200000000000003
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 21.200000000000003
#   end_time: 21.400000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 21.400000000000002
#   end_time: 21.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 21.6
#   end_time: 21.8
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 21.8
#   end_time: 22.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 22.0
#   end_time: 22.200000000000003
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 22.200000000000003
#   end_time: 22.400000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 22.400000000000002
#   end_time: 22.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 22.8
#   end_time: 23.200000000000003
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 23.200000000000003
#   end_time: 24.200000000000003
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 24.200000000000003
#   end_time: 24.400000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 24.400000000000002
#   end_time: 24.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 24.6
#   end_time: 24.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 24.8
#   end_time: 25.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 25.0
#   end_time: 25.200000000000003
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 25.200000000000003
#   end_time: 25.400000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 25.400000000000002
#   end_time: 25.6
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 25.6
#   end_time: 25.8
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 25.8
#   end_time: 26.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 26.0
#   end_time: 26.200000000000003
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 26.200000000000003
#   end_time: 26.400000000000002
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 26.400000000000002
#   end_time: 26.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 26.6
#   end_time: 26.8
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 26.8
#   end_time: 27.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 27.0
#   end_time: 27.200000000000003
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 27.200000000000003
#   end_time: 27.400000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 27.400000000000002
#   end_time: 27.6
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 27.6
#   end_time: 27.8
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 27.8
#   end_time: 28.000000000000004
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 28.000000000000004
#   end_time: 28.200000000000003
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 28.200000000000003
#   end_time: 28.400000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 28.400000000000002
#   end_time: 28.6
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 28.6
#   end_time: 28.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 28.8
#   end_time: 29.000000000000004
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 29.000000000000004
#   end_time: 29.200000000000003
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 29.200000000000003
#   end_time: 29.400000000000002
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 29.400000000000002
#   end_time: 29.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 29.6
#   end_time: 29.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 29.8
#   end_time: 30.000000000000004
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 30.000000000000004
#   end_time: 30.200000000000003
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 30.200000000000003
#   end_time: 30.400000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 30.400000000000002
#   end_time: 30.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 30.6
#   end_time: 30.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 30.8
#   end_time: 31.000000000000004
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 31.000000000000004
#   end_time: 31.200000000000003
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 31.200000000000003
#   end_time: 31.400000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 31.400000000000002
#   end_time: 31.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 31.6
#   end_time: 31.8
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 31.8
#   end_time: 32.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 32.0
#   end_time: 32.800000000000004
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 33.2
#   end_time: 33.6
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 33.6
#   end_time: 33.800000000000004
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 33.800000000000004
#   end_time: 34.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 34.0
#   end_time: 34.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 34.2
#   end_time: 34.400000000000006
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 34.400000000000006
#   end_time: 34.6
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 34.6
#   end_time: 34.800000000000004
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 34.800000000000004
#   end_time: 35.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 35.0
#   end_time: 35.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 35.2
#   end_time: 35.400000000000006
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 35.400000000000006
#   end_time: 35.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 35.6
#   end_time: 35.800000000000004
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 35.800000000000004
#   end_time: 36.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 36.0
#   end_time: 36.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 36.2
#   end_time: 36.400000000000006
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 36.400000000000006
#   end_time: 36.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 36.6
#   end_time: 36.800000000000004
# }
# notes {
#   pitch: 62
#   velocity: 92
#   start_time: 36.800000000000004
#   end_time: 37.2
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 37.2
#   end_time: 37.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 37.6
#   end_time: 38.400000000000006
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 38.400000000000006
#   end_time: 38.800000000000004
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 38.800000000000004
#   end_time: 39.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 39.2
#   end_time: 40.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 40.2
#   end_time: 40.400000000000006
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 40.400000000000006
#   end_time: 40.6
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 40.6
#   end_time: 40.800000000000004
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 40.800000000000004
#   end_time: 41.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 41.0
#   end_time: 41.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 41.2
#   end_time: 41.400000000000006
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 41.400000000000006
#   end_time: 41.6
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 41.6
#   end_time: 41.800000000000004
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 41.800000000000004
#   end_time: 42.0
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 42.0
#   end_time: 42.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 42.2
#   end_time: 42.400000000000006
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 42.400000000000006
#   end_time: 42.6
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 42.6
#   end_time: 42.800000000000004
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 42.800000000000004
#   end_time: 43.0
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 43.0
#   end_time: 43.2
# }
# notes {
#   pitch: 64
#   velocity: 92
#   start_time: 43.2
#   end_time: 43.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 43.6
#   end_time: 44.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 44.0
#   end_time: 44.800000000000004
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 44.800000000000004
#   end_time: 45.2
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 45.2
#   end_time: 45.6
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 45.6
#   end_time: 46.6
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 46.6
#   end_time: 46.800000000000004
# }
# notes {
#   pitch: 78
#   velocity: 92
#   start_time: 46.800000000000004
#   end_time: 47.0
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 47.0
#   end_time: 47.2
# }
# notes {
#   pitch: 78
#   velocity: 92
#   start_time: 47.2
#   end_time: 47.400000000000006
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 47.400000000000006
#   end_time: 47.6
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 47.6
#   end_time: 47.800000000000004
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 47.800000000000004
#   end_time: 48.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 48.0
#   end_time: 48.2
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 48.2
#   end_time: 48.400000000000006
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 48.400000000000006
#   end_time: 48.6
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 48.6
#   end_time: 48.800000000000004
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 48.800000000000004
#   end_time: 49.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 49.0
#   end_time: 49.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 49.2
#   end_time: 49.400000000000006
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 49.400000000000006
#   end_time: 49.6
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 49.6
#   end_time: 50.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 50.0
#   end_time: 50.400000000000006
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 50.400000000000006
#   end_time: 50.800000000000004
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 50.800000000000004
#   end_time: 51.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 51.0
#   end_time: 51.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 51.2
#   end_time: 51.400000000000006
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 51.400000000000006
#   end_time: 51.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 51.6
#   end_time: 51.800000000000004
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 51.800000000000004
#   end_time: 52.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 52.0
#   end_time: 52.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 52.2
#   end_time: 52.400000000000006
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 52.400000000000006
#   end_time: 52.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 52.6
#   end_time: 52.800000000000004
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 52.800000000000004
#   end_time: 53.2
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 53.2
#   end_time: 53.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 53.6
#   end_time: 54.400000000000006
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 54.400000000000006
#   end_time: 54.800000000000004
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 54.800000000000004
#   end_time: 55.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 55.2
#   end_time: 56.00000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 56.00000000000001
#   end_time: 56.400000000000006
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 56.400000000000006
#   end_time: 56.800000000000004
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 56.800000000000004
#   end_time: 57.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 57.2
#   end_time: 57.6
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 57.6
#   end_time: 58.00000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 58.00000000000001
#   end_time: 58.400000000000006
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 58.400000000000006
#   end_time: 58.800000000000004
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 58.800000000000004
#   end_time: 59.00000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 59.00000000000001
#   end_time: 59.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 59.2
#   end_time: 59.6
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 59.6
#   end_time: 60.00000000000001
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 60.00000000000001
#   end_time: 60.400000000000006
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 60.400000000000006
#   end_time: 60.800000000000004
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 60.800000000000004
#   end_time: 61.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 61.2
#   end_time: 61.6
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 61.6
#   end_time: 62.00000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 62.00000000000001
#   end_time: 62.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 62.2
#   end_time: 62.400000000000006
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 62.400000000000006
#   end_time: 62.800000000000004
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 62.800000000000004
#   end_time: 63.2
# }
# notes {
#   pitch: 64
#   velocity: 92
#   start_time: 63.2
#   end_time: 63.6
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 63.6
#   end_time: 64.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 64.0
#   end_time: 64.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 64.2
#   end_time: 64.4
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 64.4
#   end_time: 64.60000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 64.60000000000001
#   end_time: 64.8
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 64.8
#   end_time: 65.0
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 65.0
#   end_time: 65.2
# }
# notes {
#   pitch: 62
#   velocity: 92
#   start_time: 65.2
#   end_time: 65.4
# }
# notes {
#   pitch: 60
#   velocity: 92
#   start_time: 65.4
#   end_time: 65.60000000000001
# }
# notes {
#   pitch: 62
#   velocity: 92
#   start_time: 65.60000000000001
#   end_time: 66.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 66.0
#   end_time: 66.4
# }
# notes {
#   pitch: 60
#   velocity: 92
#   start_time: 66.4
#   end_time: 66.80000000000001
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 66.80000000000001
#   end_time: 67.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 67.2
#   end_time: 67.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 67.60000000000001
#   end_time: 68.0
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 68.0
#   end_time: 68.80000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 68.80000000000001
#   end_time: 69.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 69.2
#   end_time: 69.60000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 69.60000000000001
#   end_time: 70.60000000000001
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 70.60000000000001
#   end_time: 70.80000000000001
# }
# notes {
#   pitch: 81
#   velocity: 92
#   start_time: 70.80000000000001
#   end_time: 71.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 71.0
#   end_time: 71.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 71.2
#   end_time: 71.60000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 71.60000000000001
#   end_time: 71.7
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 71.7
#   end_time: 71.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 71.80000000000001
#   end_time: 72.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 72.0
#   end_time: 72.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 72.4
#   end_time: 72.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 72.60000000000001
#   end_time: 72.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 72.80000000000001
#   end_time: 73.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 73.0
#   end_time: 73.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 73.2
#   end_time: 73.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 73.4
#   end_time: 73.60000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 73.60000000000001
#   end_time: 73.80000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 73.80000000000001
#   end_time: 74.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 74.0
#   end_time: 74.2
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 74.2
#   end_time: 74.4
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 74.4
#   end_time: 74.60000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 74.60000000000001
#   end_time: 74.80000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 74.80000000000001
#   end_time: 75.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 75.0
#   end_time: 75.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 75.2
#   end_time: 75.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 75.4
#   end_time: 75.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 75.60000000000001
#   end_time: 75.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 75.80000000000001
#   end_time: 76.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 76.0
#   end_time: 76.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 76.2
#   end_time: 76.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 76.4
#   end_time: 76.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 76.60000000000001
#   end_time: 76.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 76.80000000000001
#   end_time: 77.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 77.4
#   end_time: 77.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 77.60000000000001
#   end_time: 77.7
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 77.7
#   end_time: 77.80000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 77.80000000000001
#   end_time: 78.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 78.2
#   end_time: 78.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 78.4
#   end_time: 78.80000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 78.80000000000001
#   end_time: 79.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 79.2
#   end_time: 80.2
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 80.2
#   end_time: 80.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 80.4
#   end_time: 80.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 80.60000000000001
#   end_time: 80.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 80.80000000000001
#   end_time: 81.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 81.0
#   end_time: 81.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 81.2
#   end_time: 81.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 81.4
#   end_time: 81.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 81.60000000000001
#   end_time: 82.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 82.0
#   end_time: 82.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 82.4
#   end_time: 83.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 83.4
#   end_time: 83.60000000000001
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 83.60000000000001
#   end_time: 83.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 83.80000000000001
#   end_time: 84.0
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 84.0
#   end_time: 84.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 84.2
#   end_time: 84.4
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 84.4
#   end_time: 84.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 84.60000000000001
#   end_time: 84.80000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 84.80000000000001
#   end_time: 85.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 85.0
#   end_time: 85.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 85.2
#   end_time: 85.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 85.4
#   end_time: 85.60000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 85.60000000000001
#   end_time: 85.80000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 85.80000000000001
#   end_time: 86.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 86.0
#   end_time: 86.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 86.2
#   end_time: 86.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 86.4
#   end_time: 86.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 86.60000000000001
#   end_time: 86.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 86.80000000000001
#   end_time: 87.0
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 87.0
#   end_time: 87.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 87.2
#   end_time: 87.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 87.4
#   end_time: 87.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 87.60000000000001
#   end_time: 87.80000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 87.80000000000001
#   end_time: 88.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 88.0
#   end_time: 88.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 88.2
#   end_time: 88.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 88.4
#   end_time: 88.60000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 88.60000000000001
#   end_time: 88.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 88.80000000000001
#   end_time: 89.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 89.0
#   end_time: 89.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 89.2
#   end_time: 89.4
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 89.4
#   end_time: 89.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 89.60000000000001
#   end_time: 89.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 89.80000000000001
#   end_time: 90.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 90.0
#   end_time: 90.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 90.2
#   end_time: 90.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 90.4
#   end_time: 90.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 90.60000000000001
#   end_time: 90.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 90.80000000000001
#   end_time: 91.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 91.0
#   end_time: 91.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 91.2
#   end_time: 93.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 93.0
#   end_time: 93.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 93.2
#   end_time: 93.4
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 93.4
#   end_time: 93.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 93.60000000000001
#   end_time: 93.80000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 93.80000000000001
#   end_time: 94.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 94.0
#   end_time: 94.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 94.2
#   end_time: 94.4
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 94.4
#   end_time: 94.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 94.80000000000001
#   end_time: 95.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 95.2
#   end_time: 96.2
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 96.2
#   end_time: 96.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 96.4
#   end_time: 96.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 96.60000000000001
#   end_time: 96.80000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 96.80000000000001
#   end_time: 97.0
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 97.0
#   end_time: 97.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 97.2
#   end_time: 97.4
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 97.4
#   end_time: 97.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 97.60000000000001
#   end_time: 97.80000000000001
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 97.80000000000001
#   end_time: 98.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 98.0
#   end_time: 98.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 98.2
#   end_time: 98.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 98.4
#   end_time: 98.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 98.60000000000001
#   end_time: 98.80000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 98.80000000000001
#   end_time: 99.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 99.0
#   end_time: 99.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 99.2
#   end_time: 99.4
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 99.4
#   end_time: 99.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 99.60000000000001
#   end_time: 99.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 99.80000000000001
#   end_time: 100.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 100.0
#   end_time: 100.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 100.2
#   end_time: 100.4
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 100.4
#   end_time: 100.60000000000001
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 100.60000000000001
#   end_time: 100.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 100.80000000000001
#   end_time: 101.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 101.0
#   end_time: 101.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 101.2
#   end_time: 101.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 101.4
#   end_time: 101.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 101.60000000000001
#   end_time: 101.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 101.80000000000001
#   end_time: 102.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 102.0
#   end_time: 102.2
# }
# notes {
#   pitch: 64
#   velocity: 92
#   start_time: 102.2
#   end_time: 102.4
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 102.4
#   end_time: 102.60000000000001
# }
# notes {
#   pitch: 64
#   velocity: 92
#   start_time: 102.60000000000001
#   end_time: 102.80000000000001
# }
# notes {
#   pitch: 62
#   velocity: 92
#   start_time: 102.80000000000001
#   end_time: 103.0
# }
# notes {
#   pitch: 60
#   velocity: 92
#   start_time: 103.0
#   end_time: 103.2
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 103.2
#   end_time: 103.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 103.60000000000001
#   end_time: 104.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 104.0
#   end_time: 104.10000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 104.10000000000001
#   end_time: 104.2
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 104.2
#   end_time: 104.80000000000001
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 104.80000000000001
#   end_time: 104.9
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 104.9
#   end_time: 105.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 105.0
#   end_time: 105.60000000000001
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 105.60000000000001
#   end_time: 106.0
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 106.0
#   end_time: 106.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 106.4
#   end_time: 107.2
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 107.2
#   end_time: 107.60000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 107.60000000000001
#   end_time: 108.0
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 108.0
#   end_time: 109.0
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 109.0
#   end_time: 109.2
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 109.2
#   end_time: 109.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 109.4
#   end_time: 109.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 109.60000000000001
#   end_time: 110.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 110.0
#   end_time: 110.4
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 110.4
#   end_time: 110.80000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 110.80000000000001
#   end_time: 111.2
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 111.2
#   end_time: 111.60000000000001
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 111.60000000000001
#   end_time: 112.00000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 112.00000000000001
#   end_time: 112.80000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 113.2
#   end_time: 113.60000000000001
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 113.60000000000001
#   end_time: 114.00000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 114.00000000000001
#   end_time: 114.4
# }
# notes {
#   pitch: 84
#   velocity: 92
#   start_time: 114.4
#   end_time: 115.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 115.2
#   end_time: 115.60000000000001
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 115.60000000000001
#   end_time: 116.00000000000001
# }
# notes {
#   pitch: 84
#   velocity: 92
#   start_time: 116.00000000000001
#   end_time: 116.80000000000001
# }
# notes {
#   pitch: 76
#   velocity: 92
#   start_time: 116.80000000000001
#   end_time: 117.2
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 117.2
#   end_time: 117.60000000000001
# }
# notes {
#   pitch: 84
#   velocity: 92
#   start_time: 117.60000000000001
#   end_time: 118.60000000000001
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 118.60000000000001
#   end_time: 118.80000000000001
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 118.80000000000001
#   end_time: 119.00000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 119.00000000000001
#   end_time: 119.2
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 119.2
#   end_time: 119.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 119.4
#   end_time: 119.60000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 119.60000000000001
#   end_time: 119.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 119.80000000000001
#   end_time: 120.00000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 120.00000000000001
#   end_time: 120.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 120.2
#   end_time: 120.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 120.4
#   end_time: 120.60000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 120.60000000000001
#   end_time: 120.80000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 120.80000000000001
#   end_time: 121.00000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 121.00000000000001
#   end_time: 121.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 121.2
#   end_time: 121.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 121.4
#   end_time: 121.60000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 121.60000000000001
#   end_time: 121.80000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 121.80000000000001
#   end_time: 122.00000000000001
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 122.00000000000001
#   end_time: 122.2
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 122.2
#   end_time: 122.4
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 122.4
#   end_time: 122.60000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 122.60000000000001
#   end_time: 122.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 122.80000000000001
#   end_time: 123.00000000000001
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 123.00000000000001
#   end_time: 123.2
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 123.2
#   end_time: 123.4
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 123.4
#   end_time: 123.60000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 123.60000000000001
#   end_time: 123.80000000000001
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 123.80000000000001
#   end_time: 124.00000000000001
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 124.00000000000001
#   end_time: 124.2
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 124.2
#   end_time: 124.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 124.4
#   end_time: 124.60000000000001
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 124.60000000000001
#   end_time: 124.80000000000001
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 124.80000000000001
#   end_time: 125.60000000000001
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 126.00000000000001
#   end_time: 126.4
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 126.4
#   end_time: 126.80000000000001
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 126.80000000000001
#   end_time: 127.2
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 127.2
#   end_time: 128.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 128.0
#   end_time: 128.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 128.4
#   end_time: 128.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 128.8
#   end_time: 129.6
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 129.6
#   end_time: 129.8
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 129.8
#   end_time: 130.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 130.0
#   end_time: 130.20000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 130.20000000000002
#   end_time: 130.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 130.4
#   end_time: 130.6
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 130.6
#   end_time: 130.8
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 130.8
#   end_time: 131.0
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 131.0
#   end_time: 131.20000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 131.20000000000002
#   end_time: 131.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 131.4
#   end_time: 131.6
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 131.6
#   end_time: 131.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 131.8
#   end_time: 132.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 132.0
#   end_time: 132.20000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 132.20000000000002
#   end_time: 132.4
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 132.4
#   end_time: 132.6
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 132.6
#   end_time: 132.8
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 132.8
#   end_time: 133.20000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 133.20000000000002
#   end_time: 133.60000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 133.60000000000002
#   end_time: 134.4
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 134.4
#   end_time: 134.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 134.8
#   end_time: 135.20000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 135.20000000000002
#   end_time: 136.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 136.0
#   end_time: 136.20000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 136.20000000000002
#   end_time: 136.4
# }
# notes {
#   pitch: 81
#   velocity: 92
#   start_time: 136.4
#   end_time: 136.60000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 136.60000000000002
#   end_time: 136.8
# }
# notes {
#   pitch: 81
#   velocity: 92
#   start_time: 136.8
#   end_time: 137.0
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 137.0
#   end_time: 137.20000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 137.20000000000002
#   end_time: 137.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 137.4
#   end_time: 137.60000000000002
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 137.60000000000002
#   end_time: 137.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 137.8
#   end_time: 138.0
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 138.0
#   end_time: 138.20000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 138.20000000000002
#   end_time: 138.4
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 138.4
#   end_time: 138.60000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 138.60000000000002
#   end_time: 138.8
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 138.8
#   end_time: 139.0
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 139.0
#   end_time: 139.20000000000002
# }
# notes {
#   pitch: 71
#   velocity: 92
#   start_time: 139.20000000000002
#   end_time: 139.60000000000002
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 139.60000000000002
#   end_time: 140.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 140.0
#   end_time: 140.8
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 140.8
#   end_time: 141.20000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 141.20000000000002
#   end_time: 141.60000000000002
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 141.60000000000002
#   end_time: 142.60000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 142.60000000000002
#   end_time: 142.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 142.8
#   end_time: 143.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 143.0
#   end_time: 143.20000000000002
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 143.20000000000002
#   end_time: 143.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 143.4
#   end_time: 143.60000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 143.60000000000002
#   end_time: 143.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 143.8
#   end_time: 144.0
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 144.0
#   end_time: 144.8
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 145.0
#   end_time: 145.20000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 145.20000000000002
#   end_time: 145.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 145.4
#   end_time: 145.60000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 145.60000000000002
#   end_time: 145.8
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 145.8
#   end_time: 146.0
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 146.0
#   end_time: 146.20000000000002
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 146.20000000000002
#   end_time: 146.4
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 146.4
#   end_time: 146.60000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 146.60000000000002
#   end_time: 146.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 146.8
#   end_time: 147.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 147.0
#   end_time: 147.20000000000002
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 147.20000000000002
#   end_time: 147.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 147.4
#   end_time: 147.60000000000002
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 147.60000000000002
#   end_time: 147.8
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 147.8
#   end_time: 148.0
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 148.0
#   end_time: 148.20000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 148.20000000000002
#   end_time: 148.4
# }
# notes {
#   pitch: 73
#   velocity: 92
#   start_time: 148.4
#   end_time: 148.60000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 148.60000000000002
#   end_time: 148.8
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 148.8
#   end_time: 149.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 149.0
#   end_time: 149.20000000000002
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 149.20000000000002
#   end_time: 149.4
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 149.4
#   end_time: 149.60000000000002
# }
# notes {
#   pitch: 82
#   velocity: 92
#   start_time: 149.60000000000002
#   end_time: 149.8
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 149.8
#   end_time: 150.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 150.0
#   end_time: 150.20000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 150.20000000000002
#   end_time: 150.4
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 150.4
#   end_time: 150.60000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 150.60000000000002
#   end_time: 150.8
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 150.8
#   end_time: 151.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 151.0
#   end_time: 151.20000000000002
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 151.20000000000002
#   end_time: 151.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 151.4
#   end_time: 151.60000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 151.60000000000002
#   end_time: 151.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 151.8
#   end_time: 152.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 152.0
#   end_time: 152.20000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 152.20000000000002
#   end_time: 152.4
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 152.4
#   end_time: 152.60000000000002
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 152.60000000000002
#   end_time: 152.8
# }
# notes {
#   pitch: 80
#   velocity: 92
#   start_time: 152.8
#   end_time: 153.0
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 153.0
#   end_time: 153.20000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 153.20000000000002
#   end_time: 153.4
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 153.4
#   end_time: 153.60000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 153.60000000000002
#   end_time: 153.8
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 153.8
#   end_time: 154.0
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 154.0
#   end_time: 154.20000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 154.20000000000002
#   end_time: 154.4
# }
# notes {
#   pitch: 79
#   velocity: 92
#   start_time: 154.4
#   end_time: 154.60000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 154.60000000000002
#   end_time: 154.8
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 154.8
#   end_time: 155.0
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 155.0
#   end_time: 155.20000000000002
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 155.20000000000002
#   end_time: 155.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 155.4
#   end_time: 155.60000000000002
# }
# notes {
#   pitch: 78
#   velocity: 92
#   start_time: 155.60000000000002
#   end_time: 155.8
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 155.8
#   end_time: 156.0
# }
# notes {
#   pitch: 78
#   velocity: 92
#   start_time: 156.0
#   end_time: 156.20000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 156.20000000000002
#   end_time: 156.4
# }
# notes {
#   pitch: 69
#   velocity: 92
#   start_time: 156.4
#   end_time: 156.60000000000002
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 156.60000000000002
#   end_time: 156.8
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 156.8
#   end_time: 157.0
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 157.0
#   end_time: 157.20000000000002
# }
# notes {
#   pitch: 74
#   velocity: 92
#   start_time: 157.20000000000002
#   end_time: 157.4
# }
# notes {
#   pitch: 75
#   velocity: 92
#   start_time: 157.4
#   end_time: 157.60000000000002
# }
# notes {
#   pitch: 77
#   velocity: 92
#   start_time: 157.60000000000002
#   end_time: 158.60000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 158.60000000000002
#   end_time: 158.8
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 158.8
#   end_time: 159.0
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 159.0
#   end_time: 159.20000000000002
# }
# notes {
#   pitch: 72
#   velocity: 92
#   start_time: 159.20000000000002
#   end_time: 159.4
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 159.4
#   end_time: 159.60000000000002
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 159.60000000000002
#   end_time: 159.8
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 159.8
#   end_time: 160.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 160.0
#   end_time: 160.4
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 160.4
#   end_time: 160.8
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 161.20000000000002
#   end_time: 161.8
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 161.8
#   end_time: 162.0
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 162.0
#   end_time: 162.20000000000002
# }
# notes {
#   pitch: 70
#   velocity: 92
#   start_time: 162.20000000000002
#   end_time: 162.4
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 162.4
#   end_time: 162.60000000000002
# }
# notes {
#   pitch: 67
#   velocity: 92
#   start_time: 162.60000000000002
#   end_time: 162.8
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 162.8
#   end_time: 163.0
# }
# notes {
#   pitch: 63
#   velocity: 92
#   start_time: 163.0
#   end_time: 163.20000000000002
# }
# notes {
#   pitch: 62
#   velocity: 92
#   start_time: 163.20000000000002
#   end_time: 163.60000000000002
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 163.60000000000002
#   end_time: 164.0
# }
# notes {
#   pitch: 68
#   velocity: 92
#   start_time: 164.0
#   end_time: 165.0
# }
# notes {
#   pitch: 65
#   velocity: 92
#   start_time: 165.0
#   end_time: 165.20000000000002
# }
# notes {
#   pitch: 67
#   velocity: 92
# ...
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 766.6151364458335
#   end_time: 766.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 766.9901364458335
#   end_time: 767.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 767.3651364458335
#   end_time: 768.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 769.6151364458335
#   end_time: 770.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 772.2401364458335
#   end_time: 772.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 772.6151364458335
#   end_time: 772.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 772.9901364458335
#   end_time: 773.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 773.3651364458335
#   end_time: 773.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 773.7401364458335
#   end_time: 774.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 774.1151364458335
#   end_time: 774.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 774.4901364458335
#   end_time: 774.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 774.8651364458335
#   end_time: 775.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 775.6151364458335
#   end_time: 776.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 776.3651364458335
#   end_time: 778.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 778.6151364458335
#   end_time: 780.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 780.8651364458335
#   end_time: 782.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 783.1151364458335
#   end_time: 783.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 783.8651364458335
#   end_time: 784.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 784.6151364458335
#   end_time: 785.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 785.3651364458335
#   end_time: 786.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 786.1151364458335
#   end_time: 786.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 786.8651364458335
#   end_time: 787.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 787.6151364458335
#   end_time: 789.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 789.8651364458335
#   end_time: 791.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 791.3651364458335
#   end_time: 792.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 792.1151364458335
#   end_time: 792.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 43
#   velocity: 102
#   start_time: 792.8651364458335
#   end_time: 793.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 793.6151364458335
#   end_time: 794.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 794.3651364458335
#   end_time: 795.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 796.9901364458335
#   end_time: 797.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 61
#   velocity: 102
#   start_time: 797.3651364458335
#   end_time: 797.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 797.7401364458335
#   end_time: 798.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 798.1151364458335
#   end_time: 798.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 798.4901364458335
#   end_time: 798.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 798.8651364458335
#   end_time: 799.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 799.2401364458335
#   end_time: 799.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 799.6151364458335
#   end_time: 799.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 799.9901364458335
#   end_time: 800.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 800.3651364458335
#   end_time: 800.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 800.7401364458335
#   end_time: 801.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 801.1151364458335
#   end_time: 801.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 801.8651364458335
#   end_time: 802.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 802.6151364458335
#   end_time: 802.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 803.3651364458335
#   end_time: 804.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 804.8651364458335
#   end_time: 805.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 805.6151364458335
#   end_time: 806.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 806.3651364458335
#   end_time: 807.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 807.1151364458335
#   end_time: 807.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 47
#   velocity: 102
#   start_time: 807.8651364458335
#   end_time: 808.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 808.2401364458335
#   end_time: 808.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 808.6151364458335
#   end_time: 808.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 808.9901364458335
#   end_time: 809.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 809.3651364458335
#   end_time: 809.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 52
#   velocity: 102
#   start_time: 809.7401364458335
#   end_time: 810.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 41
#   velocity: 102
#   start_time: 810.1151364458335
#   end_time: 810.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 810.8651364458335
#   end_time: 812.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 812.3651364458335
#   end_time: 813.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 813.3026364458335
#   end_time: 813.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 813.4901364458335
#   end_time: 813.6823239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 813.6776364458335
#   end_time: 813.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 813.8651364458335
#   end_time: 814.0573239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 814.0526364458335
#   end_time: 814.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 814.2401364458335
#   end_time: 814.4323239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 814.4276364458335
#   end_time: 814.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 814.6151364458335
#   end_time: 814.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 814.9901364458335
#   end_time: 815.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 815.3651364458335
#   end_time: 815.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 815.7401364458335
#   end_time: 816.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 816.1151364458335
#   end_time: 816.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 816.4901364458335
#   end_time: 816.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 816.8651364458335
#   end_time: 817.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 61
#   velocity: 102
#   start_time: 817.2401364458335
#   end_time: 817.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 817.6151364458335
#   end_time: 817.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 61
#   velocity: 102
#   start_time: 817.9901364458335
#   end_time: 818.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 818.3651364458335
#   end_time: 818.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 61
#   velocity: 102
#   start_time: 818.7401364458335
#   end_time: 819.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 819.1151364458335
#   end_time: 819.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 819.4901364458335
#   end_time: 819.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 819.8651364458335
#   end_time: 820.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 820.2401364458335
#   end_time: 820.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 820.6151364458335
#   end_time: 820.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 820.9901364458335
#   end_time: 821.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 44
#   velocity: 102
#   start_time: 821.3651364458335
#   end_time: 821.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 821.7401364458335
#   end_time: 822.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 44
#   velocity: 102
#   start_time: 822.1151364458335
#   end_time: 822.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 822.4901364458335
#   end_time: 822.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 44
#   velocity: 102
#   start_time: 822.8651364458335
#   end_time: 823.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 823.2401364458335
#   end_time: 823.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 823.6151364458335
#   end_time: 823.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 823.9901364458335
#   end_time: 824.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 824.3651364458335
#   end_time: 824.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 824.7401364458335
#   end_time: 825.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 825.1151364458335
#   end_time: 825.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 53
#   velocity: 102
#   start_time: 825.4901364458335
#   end_time: 825.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 825.8651364458335
#   end_time: 826.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 826.2401364458335
#   end_time: 826.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 826.6151364458335
#   end_time: 826.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 826.9901364458335
#   end_time: 827.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 49
#   velocity: 102
#   start_time: 827.3651364458335
#   end_time: 827.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 827.7401364458335
#   end_time: 828.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 828.1151364458335
#   end_time: 828.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 828.4901364458335
#   end_time: 828.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 828.8651364458335
#   end_time: 829.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 829.2401364458335
#   end_time: 829.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 829.6151364458335
#   end_time: 829.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 829.9901364458335
#   end_time: 830.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 830.3651364458335
#   end_time: 831.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 832.6151364458335
#   end_time: 832.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 832.9901364458335
#   end_time: 833.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 41
#   velocity: 102
#   start_time: 833.3651364458335
#   end_time: 833.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 833.7401364458335
#   end_time: 834.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 43
#   velocity: 102
#   start_time: 834.1151364458335
#   end_time: 834.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 834.4901364458335
#   end_time: 834.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 44
#   velocity: 102
#   start_time: 834.8651364458335
#   end_time: 835.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 835.2401364458335
#   end_time: 835.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 835.6151364458335
#   end_time: 835.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 835.9901364458335
#   end_time: 836.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 48
#   velocity: 102
#   start_time: 836.3651364458335
#   end_time: 836.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 836.7401364458335
#   end_time: 837.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 837.1151364458335
#   end_time: 837.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 837.4901364458335
#   end_time: 837.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 44
#   velocity: 102
#   start_time: 837.8651364458335
#   end_time: 838.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 838.2401364458335
#   end_time: 838.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 46
#   velocity: 102
#   start_time: 838.6151364458335
#   end_time: 838.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 50
#   velocity: 102
#   start_time: 838.9901364458335
#   end_time: 839.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 839.3651364458335
#   end_time: 840.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 39
#   velocity: 102
#   start_time: 841.6151364458335
#   end_time: 842.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 844.2401364458335
#   end_time: 844.6198239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 844.6151364458335
#   end_time: 844.9948239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 844.9901364458335
#   end_time: 845.3698239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 845.3651364458335
#   end_time: 845.7448239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 845.7401364458335
#   end_time: 846.1198239458334
#   instrument: 2
# }
# notes {
#   pitch: 55
#   velocity: 102
#   start_time: 846.1151364458335
#   end_time: 846.4948239458334
#   instrument: 2
# }
# notes {
#   pitch: 60
#   velocity: 102
#   start_time: 846.4901364458335
#   end_time: 846.8698239458334
#   instrument: 2
# }
# notes {
#   pitch: 56
#   velocity: 102
#   start_time: 846.8651364458335
#   end_time: 847.2448239458334
#   instrument: 2
# }
# notes {
#   pitch: 58
#   velocity: 102
#   start_time: 847.6151364458335
#   end_time: 848.3745114458335
#   instrument: 2
# }
# notes {
#   pitch: 51
#   velocity: 102
#   start_time: 848.3670114458334
#   end_time: 851.9745114458334
#   instrument: 2
# }
# total_time: 851.9745114458334
# source_info {
#   encoding_type: MIDI
#   parser: PRETTY_MIDI
# }

# %%
print(sequence_midi.notes[0])
print(sequence_midi.notes[1])
print(sequence_midi.notes[2880])
# Out:
# pitch: 70
# velocity: 92
# start_time: 6.4
# end_time: 6.800000000000001
#
# pitch: 74
# velocity: 92
# start_time: 6.800000000000001
# end_time: 7.2
#
# pitch: 69
# velocity: 97
# start_time: 139.8
# end_time: 140.0
# instrument: 1
# program: 19

# %% [markdown]
# 换了一个MIDI数据集中的MIDI文件，似乎还是这样。具体原因我再寻找一下，在下一节时分析。

# %% [markdown]
# ## 总结
# 我们了解了Magenta项目原始数据整合的过程，并了解了读取MIDI和XML的函数。
#
# 如果你想进行自己的项目的话，直接用Magenta的数据处理函数也是个不错的选择。
#
# 同时，也有其他的数据读取与处理方式，例如Magenta.piplines类，pretty_midi库，都是不错的选择。但在这里就不详细展开了，也许在之后的教程里会提到。
#
# 对于读取到的MIDI数据以及XML数据的解释，我会在下一节中说明。
#
# 最后，对于生成的tfrecord，Magenta将数据转换成了二进制字符储存，读取稍微有些复杂，我们有机会再详细说明。
